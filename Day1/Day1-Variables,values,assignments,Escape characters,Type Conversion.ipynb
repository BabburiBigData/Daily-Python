# %%
a=10
print(a)
print(type(a))
a=20.0
print(a)
print(type(a))
a=True
print(a)
print(type(a))
a='sai'
print(a)
print(type(a))
a=3+4j
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>
# 20.0
# <class 'float'>
# True
# <class 'bool'>
# sai
# <class 'str'>
# (3+4j)
# <class 'complex'>

# %%
##another important trick to remeber is exchanging of values
a=10
b=20
print('a=',a)
print('b=',b)
c=a
a=b
b=c
print(a,b)
# Out:
# a= 10
# b= 20
# 20 10

# %%
##escape characters
print("sai \nis \na good boy")
a="1\t2\t3\t4\t"
print(a)
# Out:
# sai
# is
# a good boy
# 1	2	3	4

# %%
print('"sai vardhan is good",really how\'re you doing')
print('\'sai vardhan is good\',really how\'re you doing')
print(""" hello boy""")
print(""" hello \
boy""")
print("c:\\Users\\tim\\desktop")
print(r"c:\\Users\\tim\\desktop")
# Out:
# "sai vardhan is good",really how're you doing
# 'sai vardhan is good',really how're you doing
#  hello boy
#  hello boy
# c:\Users\tim\desktop
# c:\\Users\\tim\\desktop

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=10
b=10
print(id(a))
print(id(b))
# Out:
# 2286430087760
# 2286430087760

# %%
#various assignments
a=b=10
print(a,b)
print(id(a),id(b))
a,b,c=5,10,15
print(a,b,c)
# Out:
# 10 10
# 2286430087760 2286430087760
# 5 10 15

# %%
#Type Conversion
print(int(10.5))
print(int('10'))
print(float(10))
# Out:
# 10
# 10
# 10.0
# <class 'str'>

# %%
print((float(10.5)))
print(float(10))
print(float("100"))
print(float("10.5"))
# Out:
# 10.5
# 10.0
# 100.0
# 10.5

# %%
print(type(str(5)))
print(type(str(10.0)))
print(type(str('sai')))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
print(str(5)+str('hello'))
# Out:
# 5hello

# %%
age=10
print(age+7)
age=(10==2)
print(age)
a=True
print(a)
# Out:
# 17
# False
# True

# %%
a=1
a=a+1
print(a)

a=2
a+=1
print(a)

word='race'
word+='car'
print(word)
# Out:
# 2
# 3
# racecar

# %%
b=5
b=b*3
print(b)

b=3
b*=5
print(b)

## -= ,/=
# Out:
# 15
# 15
